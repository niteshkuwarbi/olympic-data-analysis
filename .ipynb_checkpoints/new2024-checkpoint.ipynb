# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
athletes = pd.read_csv(r'C:\Users\HP\Downloads\athletes.csv')
medallists = pd.read_csv(r'C:\Users\HP\Downloads\medallists.csv')
medals = pd.read_csv(r'C:\Users\HP\Downloads\medals.csv')

# %%
athletes.head()
# Out:
#    athlete_id               name  NOC   Region  Height(cm)  Weight(kg)  \
# 0     1532872   ALEKSANYAN Artur  ARM  Armenia           0         0.0
# 1     1532873     AMOYAN Malkhas  ARM  Armenia           0         0.0
# 2     1532874    GALSTYAN Slavik  ARM  Armenia           0         0.0
# 3     1532944  HARUTYUNYAN Arsen  ARM  Armenia           0         0.0
# 4     1532945    TEVANYAN Vazgen  ARM  Armenia           0         0.0
#
#        Sport                   Event         DOB
# 0  Wrestling  Men's Greco-Roman 97kg  21-10-1991
# 1  Wrestling  Men's Greco-Roman 77kg  22-01-1999
# 2  Wrestling  Men's Greco-Roman 67kg  21-12-1996
# 3  Wrestling    Men's Freestyle 57kg  22-11-1999
# 4  Wrestling    Men's Freestyle 65kg  27-10-1999

# %%
medallists.head()
# Out:
#    athlete_id             name  NOC         Region    Sport  \
# 0     1903136  EVENEPOEL Remco  BEL        Belgium  Cycling
# 1     1923520    GANNA Filippo  ITA          Italy  Cycling
# 2     1903147    van AERT Wout  BEL        Belgium  Cycling
# 3     1940173      BROWN Grace  AUS      Australia  Cycling
# 4     1912525   HENDERSON Anna  GBR  Great Britain  Cycling
#
#                            Event         DOB    Medal Team
# 0    Men's Individual Time Trial  25-01-2000    Gold   NaN
# 1    Men's Individual Time Trial  25-07-1996  Silver   NaN
# 2    Men's Individual Time Trial  15-09-1994  Bronze   NaN
# 3  Women's Individual Time Trial  07-07-1992    Gold   NaN
# 4  Women's Individual Time Trial  14-11-1998  Silver   NaN

# %%
athletes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11110 entries, 0 to 11109
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   athlete_id  11110 non-null  int64
#  1   name        11110 non-null  object
#  2   NOC         11110 non-null  object
#  3   Region      11110 non-null  object
#  4   Height(cm)  11110 non-null  int64
#  5   Weight(kg)  11108 non-null  float64
#  6   Sport       11110 non-null  object
#  7   Event       11110 non-null  object
#  8   DOB         11110 non-null  object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 781.3+ KB

# %%
medallists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2315 entries, 0 to 2314
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   athlete_id  2315 non-null   int64
#  1   name        2312 non-null   object
#  2   NOC         2312 non-null   object
#  3   Region      2312 non-null   object
#  4   Sport       2315 non-null   object
#  5   Event       2315 non-null   object
#  6   DOB         2312 non-null   object
#  7   Medal       2315 non-null   object
#  8   Team        1555 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 162.9+ KB

# %%
merged_df = pd.merge(athletes, medallists, on=['athlete_id', 'name', 'NOC', 'Region', 'Sport', 'Event', 'DOB'], how='left')

# %%
merged_df.head()
# Out:
#    athlete_id               name  NOC   Region  Height(cm)  Weight(kg)  \
# 0     1532872   ALEKSANYAN Artur  ARM  Armenia           0         0.0
# 1     1532873     AMOYAN Malkhas  ARM  Armenia           0         0.0
# 2     1532874    GALSTYAN Slavik  ARM  Armenia           0         0.0
# 3     1532944  HARUTYUNYAN Arsen  ARM  Armenia           0         0.0
# 4     1532945    TEVANYAN Vazgen  ARM  Armenia           0         0.0
#
#        Sport                   Event         DOB    Medal Team
# 0  Wrestling  Men's Greco-Roman 97kg  21-10-1991  Silver   NaN
# 1  Wrestling  Men's Greco-Roman 77kg  22-01-1999  Bronze   NaN
# 2  Wrestling  Men's Greco-Roman 67kg  21-12-1996      NaN  NaN
# 3  Wrestling    Men's Freestyle 57kg  22-11-1999      NaN  NaN
# 4  Wrestling    Men's Freestyle 65kg  27-10-1999      NaN  NaN

# %%
merged_df['Year'] = 2024.0

# %%
merged_df['Type'] = 'Summer'

# %%
merged_df
# Out:
#        athlete_id                        name  NOC               Region  \
# 0         1532872            ALEKSANYAN Artur  ARM              Armenia
# 1         1532873              AMOYAN Malkhas  ARM              Armenia
# 2         1532874             GALSTYAN Slavik  ARM              Armenia
# 3         1532944           HARUTYUNYAN Arsen  ARM              Armenia
# 4         1532945             TEVANYAN Vazgen  ARM              Armenia
# ...           ...                         ...  ...                  ...
# 11105     4982175               JOSEPH Elijah  TTO  Trinidad and Tobago
# 11106     4982762             HOMAN Khrystyna  UKR              Ukraine
# 11107     4983537  CHELANGAT Annet Chemengich  UGA               Uganda
# 11108     4986655              ADA ETO Sefora  GEQ    Equatorial Guinea
# 11109     9460001             LIUZZI Emanuela  ITA                Italy
#
#        Height(cm)  Weight(kg)      Sport                   Event         DOB  \
# ...

# %%
merged_df.duplicated().sum()
# Out:
# 0

# %%
merged_df['Medal'].value_counts()
# Out:
# Medal
# Bronze     488
# Silver     460
# Gold       440
# Name: count, dtype: int64

# %%
new_df = pd.concat([merged_df, pd.get_dummies(merged_df['Medal'])],axis=1)

# %%
new_df.to_csv('new_df.csv', index=False)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11110 entries, 0 to 11109
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   athlete_id  11110 non-null  int64
#  1   name        11110 non-null  object
#  2   NOC         11110 non-null  object
#  3   Region      11110 non-null  object
#  4   Height(cm)  11110 non-null  int64
#  5   Weight(kg)  11108 non-null  float64
#  6   Sport       11110 non-null  object
#  7   Event       11110 non-null  object
#  8   DOB         11110 non-null  object
#  9   Medal       1388 non-null   object
#  10  Team        948 non-null    object
#  11  Year        11110 non-null  float64
#  12  Type        11110 non-null  object
#  13  Bronze      11110 non-null  bool
#  14  Gold        11110 non-null  bool
#  15  Silver      11110 non-null  bool
# dtypes: bool(3), float64(2), int64(2), object(9)
# memory usage: 1.1+ MB

# %%
new_df = pd.read_csv('new_df.csv')

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11110 entries, 0 to 11109
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   athlete_id  11110 non-null  int64
#  1   name        11110 non-null  object
#  2   NOC         11110 non-null  object
#  3   Region      11110 non-null  object
#  4   Height(cm)  11110 non-null  int64
#  5   Weight(kg)  11108 non-null  float64
#  6   Sport       11110 non-null  object
#  7   Event       11110 non-null  object
#  8   DOB         11110 non-null  object
#  9   Medal       1388 non-null   object
#  10  Team        948 non-null    object
#  11  Year        11110 non-null  float64
#  12  Type        11110 non-null  object
#  13  Bronze      11110 non-null  bool
#  14  Gold        11110 non-null  bool
#  15  Silver      11110 non-null  bool
# dtypes: bool(3), float64(2), int64(2), object(9)
# memory usage: 1.1+ MB

# %%
new_df['Medal'].unique()
# Out:
# array(['Silver ', 'Bronze ', nan, 'Gold '], dtype=object)

# %%
new_df['Medal'] = new_df['Medal'].str.strip().str.capitalize()

# %%
new_df['Medal'].value_counts()
# Out:
# Medal
# Bronze    488
# Silver    460
# Gold      440
# Name: count, dtype: int64

# %%
new_df.to_csv('new_df.csv', index=False)

# %%
new_df.head()
# Out:
#    athlete_id               name  NOC   Region  Height(cm)  Weight(kg)  \
# 0     1532872   ALEKSANYAN Artur  ARM  Armenia           0         0.0
# 1     1532873     AMOYAN Malkhas  ARM  Armenia           0         0.0
# 2     1532874    GALSTYAN Slavik  ARM  Armenia           0         0.0
# 3     1532944  HARUTYUNYAN Arsen  ARM  Armenia           0         0.0
# 4     1532945    TEVANYAN Vazgen  ARM  Armenia           0         0.0
#
#        Sport                   Event         DOB   Medal Team    Year    Type  \
# 0  Wrestling  Men's Greco-Roman 97kg  21-10-1991  Silver  NaN  2024.0  Summer
# 1  Wrestling  Men's Greco-Roman 77kg  22-01-1999  Bronze  NaN  2024.0  Summer
# 2  Wrestling  Men's Greco-Roman 67kg  21-12-1996     NaN  NaN  2024.0  Summer
# 3  Wrestling    Men's Freestyle 57kg  22-11-1999     NaN  NaN  2024.0  Summer
# 4  Wrestling    Men's Freestyle 65kg  27-10-1999     NaN  NaN  2024.0  Summer
#
#    Bronze   Gold   Silver
# 0    False  False     True
# ...

# %%
new_df['Sport']
# Out:
# 0        Wrestling
# 1        Wrestling
# 2        Wrestling
# 3        Wrestling
# 4        Wrestling
#            ...
# 11105    Athletics
# 11106         Judo
# 11107    Athletics
# 11108    Athletics
# 11109    Wrestling
# Name: Sport, Length: 11110, dtype: object
